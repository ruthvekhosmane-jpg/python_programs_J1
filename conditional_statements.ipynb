# %% [markdown]
# # conditional statements in python
# 1.pytho have 4 types of conditional statements
# 2.`if` statements
# 3.`elif` statement
# 4.`else` statement
# 5.`nested` statements
#
# ```python
# if (condition)
#     statements
#     statements..
#  ```
#
# ```python if,else
# if (condition)
#     statements
#     statements...
#  ```
#
#  ```python if,elif,else
#  if (condition):
#      statement-
#  elif (condition):
#      statements
#  elif (condition):
#      statements
#  else:
#      statements..
#  ```

# %%
#write a program to find the given number is even number
num=int(input("please enter number here:"))
if(num%2==0):
   print(num,"is even number")
# Out:
# please enter number here: 78
# 78 is even number

# %%
#write a program to find the given number is even number or odd number
number=int(input("please enter number here:"))
if (number%2==0):
    print(number,"is even number")
else:
     print(number,"is odd number")
# Out:
# please enter number here: 4527
# 4527 is odd number

# %%
#write a program to find the given b=number is positive or negative or zero
number = int(input("please enter number here:"))
if (number>0):
   print(number,"is positive number")
elif (number<0):
    print (number,"is negative number")
else: 
    print(number,"is zero")
# Out:
# please enter number here: 0
# 0 is zero

# %%
"""
write a program find the student grades based on  marks
1.if student marks in between 100 to 80 then grade is A
2.if student marks in beween 79 to 60 then grade is B
2.if student marks in between 59 to 40 then geade is C
4.if student marks in between 39 to 25 then grade is D
5.if student marks in between 24 to 0 then grade is E
6. if other than obve marks expected output should be please enter correct marks!
"""
marks=int(input("enter student marks here"))
if (marks>=80 and marks<=100):
    print(marks,"is A grade")
elif (marks>=60 and marks<=79):
    print(marks,"is B grade")
elif (marks>=40 and  marks<=59):
    print(marks,"is c grade")
elif (marks>=25 and marks<=39):
    print(marks,"is D grade")
elif (marks>=0 and marks<=24):
    print(marks,"is fail")
else:
    print(marks,"is not correct marks, please enter the correct marks")
# Out:
# enter student marks here 85
# 85 is A grade

# %%
#write a program find the largest number from three numbers
#write a program to find the leap year or non leap year
#write a program to check login credintals using conditional statements

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third numbrer"))
if(num1 >=num2) and (num1 >=num3):
         largest=num1
elif (num2 >=num1) and (num2 >=num3):
       largest = num3
print("the largest number is:",largest)
# Out:
# enter the first number 09
# enter the second number 89
# enter the third numbrer 89
# the largest number is: 89

# %%
year=int(input("enter year here:")
if (year%4==0):
    if(year%100==0):
    if(year%400==0):
        print(year,"is leap year")
    else:
         print
